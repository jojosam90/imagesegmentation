# %% [markdown]
# <a href="https://colab.research.google.com/github/jojosam90/imagesegmentation/blob/main/maskrcnn_keypoint_poseestimation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# reference  https://github.com/FangYang970206/MaskRCNN-Keypoint-Demo

# %%
# !git clone https://github.com/FangYang970206/MaskRCNN-Keypoint-Demo
# Out:
# Cloning into 'MaskRCNN-Keypoint-Demo'...
# remote: Enumerating objects: 39, done.
# remote: Total 39 (delta 0), reused 0 (delta 0), pack-reused 39
# Unpacking objects: 100% (39/39), done.

# %%
cd MaskRCNN-Keypoint-Demo
# Out:
# [Errno 2] No such file or directory: 'MaskRCNN-Keypoint-Demo'
# /content/MaskRCNN-Keypoint-Demo/MaskRCNN-Keypoint-Demo

# %%
# !wget https://www.dropbox.com/s/5ctrg3br94srrx9/mask_rcnn_coco.h5
# Out:
# --2022-05-10 00:22:32--  https://www.dropbox.com/s/5ctrg3br94srrx9/mask_rcnn_coco.h5
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.18, 2620:100:601d:18::a27d:512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/5ctrg3br94srrx9/mask_rcnn_coco.h5 [following]
# --2022-05-10 00:22:33--  https://www.dropbox.com/s/raw/5ctrg3br94srrx9/mask_rcnn_coco.h5
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc53ebd6964d17ff7aa2de2890c1.dl.dropboxusercontent.com/cd/0/inline/Bk_DQiewOPFGPkGNDXY9uwrk-h1Gxhfa12vJVX3SPmQlYSbZM7-oRYj0Xn1BtQ3yvkIen-m51BLWfxom_Y8LBOnyaQTiu0m5HJw-Otb5O6Y3wnopRTtsWy7NBKBbJGXo8061fZfP3gDzGKRdY8CTt-MSp-p03lGBkTmoOuWjuGT5kw/file# [following]
# ...

# %%
# !ls
# Out:
# coco.py     demo.ipynb	mask_rcnn_coco.h5    model.py	  utils.py
# colors.txt  gif		mask_rcnn_coco.h5.1  __pycache__
# config.py   main.py	media		     README.md

# %%
# !pip install imgaug==0.2.5
# !pip install folium==0.2.1
# !pip install -q pillow
# !pip install -q h5py
# !pip install opencv-python
# !pip install -U scikit-image
# !pip install -U cython
# !pip install "git+https://github.com/philferriere/cocoapi.git#egg=pycocotools&subdirectory=PythonAPI"
# !pip install keras==2.1.6 --force-reinstall
# !pip install six==1.12.0
# !pip install scipy==1.1.0

# %%
import cv2 as cv 
import numpy as np
import matplotlib.pyplot as plt

def load(name):
    """
    Given an url of an image, downloads the image and
    returns a PIL image
    """
    image = cv.imread(name)
    # convert to BGR format
    image = np.array(image)
    return image
  
def imshow(img):
    plt.imshow(img[:, :, [2, 1, 0]])
    plt.axis("off")

# %%
image = load("media/ski.jpg")
imshow(image)

# %%
# !python main.py --image media/ski.jpg
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.7/dist-packages/skimage/io/manage_plugins.py:23: UserWarning: Your installed pillow version is < 8.1.2. Several security issues (CVE-2021-27921, CVE-2021-25290, CVE-2021-25291, CVE-2021-25293, and more) have been fixed in pillow 8.1.2 or higher. We recommend to upgrade this library.
#   from .collection import imread_collection_wrapper
# Traceback (most recent call last):
#   File "main.py", line 139, in <module>
#     main()
#   File "main.py", line 45, in main
#     config=inference_config)
#   File "/content/MaskRCNN-Keypoint-Demo/MaskRCNN-Keypoint-Demo/model.py", line 2516, in __init__
#     self.keras_model = self.build(mode=mode, config=config)
#   File "/content/MaskRCNN-Keypoint-Demo/MaskRCNN-Keypoint-Demo/model.py", line 2535, in build
#     shape=config.IMAGE_SHAPE.tolist(), name="input_image")
#   File "/usr/local/lib/python3.7/dist-packages/keras/engine/topology.py", line 1457, in Input
#     input_tensor=tensor)
# ...

# %%
image_out = load("media/ski_mask_rcnn_out_py.jpg")
imshow(image_out)
